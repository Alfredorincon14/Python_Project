# %%
import csv

import os

file_to_analyze='C:/Users/A/Desktop/DataViz/Classwork/03-Python/Instructions/PyBank/Resources/budget_data.csv'

file_to_output='Analysis_2.text'


with open(file_to_analyze) as csvfile:

    reader= csv.DictReader(csvfile)
    
    total_months=1

    rev_change=0

    rev_change_list=[]

    monthly_rev_change =[]

    greatest_decrease= ["",0]

    greatest_increase=["",0]

    prev_rev=int(next(reader)['Profit/Losses'])

    total_rev=prev_rev

    for row in reader:

        total_months += 1

        total_rev += int(row["Profit/Losses"])


        rev_change = int(row["Profit/Losses"])-prev_rev

        prev_rev = int(row["Profit/Losses"])

        rev_change_list.append(rev_change)
        months.append(row("Date"))

        if (rev_change > greatest_increase[1]):
            greatest_increase[0] = row["Date"]
            greatest_increase[1] = rev_change

        
        if (rev_change < greatest_decrease[1]):
            greatest_decrease[0] = row["Date"]
            greatest_decrease[1] = rev_change

    print('Financial Analysis')

    print('----------------------------')

    print(f'Total Months: {total_months}')

    print(f'Total: ${total_rev:,}')

    print(f'Average Change: ${sum(rev_change_list)/(total_months-1):,.2f}')

    print(f'Greatest Increase in Profits: {greatest_increase[0]} ${greatest_increase[1]}')

    print(f'Greatest Decrease in Profits: {greatest_decrease[0]} ${greatest_decrease[1]}')
    
    #os.mkdir('Analysis_2')
    
    with open(file_to_output, "w") as txt_file:

        txt_file.write("Financial Analysis")
        txt_file.write("\n")
        txt_file.write("-------------------------------------------------------------------------------")
        txt_file.write("\n")
        txt_file.write(f'Total Months: {total_months}')
        txt_file.write("\n")
        txt_file.write(f'Total: ${total_rev:,}')
        txt_file.write("\n")
        txt_file.write(f'Average Change: ${sum(rev_change_list)/(total_months-1):,.2f}')
        txt_file.write("\n")
        txt_file.write(f'Average Change: ${sum(rev_change_list)/(total_months-1):,.2f}')
        txt_file.write("\n")
        txt_file.write(f'Greatest Increase in Profits: {greatest_increase[0]} ${greatest_increase[1]}')
        txt_file.write("\n")
        txt_file.write(f'Greatest Decrease in Profits: {greatest_decrease[0]} ${greatest_decrease[1]}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-e97cb63a537f> in <module>
#      40
#      41         rev_change_list.append(rev_change)
# ---> 42         months.append(row("Date"))
#      43
#      44         if (rev_change > greatest_increase[1]):
#
# AttributeError: 'int' object has no attribute 'append'
